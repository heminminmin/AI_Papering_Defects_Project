# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), os.path.pardir, 'functions'))

from compare_csv_fn import compare_with_sample_csv_fn
from compare_csv_fn import compare_with_prev_csv_fn

# 최고점 54점인 베이스라인 파일과 테스트 결과 라벨 비교
PREV_CSV_FILE_NAME = 'baseline_submit.csv'
CURRENT_CSV_FILE_NAME = 'test_20230504_045201.csv'

PREV_FOLDER_NAME = '2_second'
CURRENT_FOLDER_NAME = '9_nineth'

compare_with_sample_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME)
compare_with_sample_csv_fn(CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)

compare_with_prev_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME, CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)
# Out:
# compare_with_sample_csv_fn() : 462
# compare_with_sample_csv_fn() : 277
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 몰딩수정 오염
# 훼손 터짐
# 몰딩수정 터짐
# 피스 오타공
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 석고수정 훼손
# 걸레받이수정 훼손
# 오염 훼손
# 오염 훼손
# 오염 창틀,문틀수정
# 훼손 몰딩수정
# 오염 훼손
# 훼손 오염
# 훼손 창틀,문틀수정
# 훼손 오염
# 터짐 오염
# 곰팡이 꼬임
# 오염 훼손
# 곰팡이 오염
# 훼손 오염
# 훼손 터짐
# 오타공 훼손
# 몰딩수정 훼손
# 오염 훼손
# 훼손 터짐
# 면불량 훼손
# 훼손 터짐
# 걸레받이수정 훼손
# 오염 훼손
# 오염 훼손
# 오염 오타공
# 훼손 오염
# 훼손 터짐
# 오염 훼손
# 오타공 훼손
# 몰딩수정 터짐
# 오염 터짐
# 오염 훼손
# 터짐 훼손
# 오염 훼손
# 꼬임 오염
# 훼손 터짐
# 오염 터짐
# 걸레받이수정 훼손
# 오염 오타공
# 면불량 오염
# 석고수정 훼손
# 오염 훼손
# 훼손 오타공
# 들뜸 훼손
# 터짐 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 꼬임
# 오염 훼손
# 훼손 터짐
# 훼손 오타공
# 오염 훼손
# 훼손 오염
# 훼손 터짐
# 터짐 훼손
# 가구수정 훼손
# 몰딩수정 훼손
# 터짐 오염
# 훼손 오염
# 오염 훼손
# 훼손 터짐
# 오염 훼손
# 훼손 오염
# 꼬임 창틀,문틀수정
# 곰팡이 훼손
# 훼손 터짐
# 터짐 훼손
# 오염 훼손
# 꼬임 훼손
# 오염 훼손
# 오염 훼손
# 면불량 훼손
# 오염 터짐
# 오타공 훼손
# 오염 훼손
# 오염 훼손
# 오타공 훼손
# 훼손 오염
# 훼손 오염
# 꼬임 훼손
# 오염 훼손
# 이음부불량 터짐
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 훼손 오염
# 오염 훼손
# 꼬임 훼손
# ...

# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), os.path.pardir, 'functions'))

from compare_csv_fn import compare_with_sample_csv_fn
from compare_csv_fn import compare_with_prev_csv_fn

# 48점인 파일과 테스트 결과 라벨 비교
PREV_CSV_FILE_NAME = 'baseline_submit.csv'
CURRENT_CSV_FILE_NAME = 'test_20230504_045201.csv'

PREV_FOLDER_NAME = '8_eightth'
CURRENT_FOLDER_NAME = '9_nineth'

compare_with_sample_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME)
compare_with_sample_csv_fn(CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)

compare_with_prev_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME, CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)
# Out:
# compare_with_sample_csv_fn() : 447
# compare_with_sample_csv_fn() : 277
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 몰딩수정 오염
# 훼손 오염
# 훼손 터짐
# 훼손 오염
# 몰딩수정 터짐
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 피스 훼손
# 걸레받이수정 훼손
# 오염 훼손
# 훼손 몰딩수정
# 오염 훼손
# 터짐 오염
# 꼬임 창틀,문틀수정
# 훼손 오염
# 곰팡이 꼬임
# 오염 훼손
# 곰팡이 오염
# 훼손 오염
# 훼손 터짐
# 오타공 훼손
# 꼬임 훼손
# 면불량 훼손
# 오염 훼손
# 훼손 오타공
# 훼손 오염
# 훼손 터짐
# 오염 훼손
# 오타공 훼손
# 몰딩수정 터짐
# 오염 터짐
# 오염 훼손
# 터짐 훼손
# 훼손 오염
# 오염 훼손
# 오타공 훼손
# 터짐 훼손
# 오염 터짐
# 오염 터짐
# 오염 오타공
# 훼손 오염
# 면불량 훼손
# 훼손 오타공
# 창틀,문틀수정 훼손
# 터짐 훼손
# 면불량 훼손
# 오염 훼손
# 오염 훼손
# 훼손 꼬임
# 오염 훼손
# 훼손 오타공
# 오염 훼손
# 훼손 오염
# 훼손 터짐
# 터짐 훼손
# 꼬임 훼손
# 훼손 오염
# 훼손 오염
# 훼손 터짐
# 오염 훼손
# 훼손 오염
# 오염 창틀,문틀수정
# 터짐 훼손
# 훼손 터짐
# 몰딩수정 훼손
# 꼬임 훼손
# 오염 훼손
# 오염 훼손
# 녹오염 훼손
# 훼손 터짐
# 녹오염 훼손
# 오염 훼손
# 걸레받이수정 오염
# 훼손 오염
# 꼬임 훼손
# 오염 훼손
# 이음부불량 터짐
# 오염 훼손
# 오염 훼손
# 터짐 훼손
# 면불량 훼손
# 곰팡이 훼손
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 곰팡이 훼손
# 훼손 오염
# 오염 훼손
# 꼬임 훼손
# 울음 터짐
# 훼손 오타공
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 터짐
# 꼬임 훼손
# 꼬임 훼손
# 꼬임 터짐
# 꼬임 오염
# 훼손 터짐
# 훼손 오염
# 꼬임 훼손
# ...

# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), os.path.pardir, 'functions'))

from compare_csv_fn import compare_with_sample_csv_fn
from compare_csv_fn import compare_with_prev_csv_fn

# 24점인 이미지 증강 전 파일과 테스트 결과 라벨 비교
PREV_CSV_FILE_NAME = 'test_20230501_213749.csv'
CURRENT_CSV_FILE_NAME = 'test_20230504_045201.csv'

PREV_FOLDER_NAME = '7_seventh'
CURRENT_FOLDER_NAME = '9_nineth'

compare_with_sample_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME)
compare_with_sample_csv_fn(CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)

compare_with_prev_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME, CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)
# Out:
# compare_with_sample_csv_fn() : 455
# compare_with_sample_csv_fn() : 277
# 터짐 오염
# 오염 훼손
# 훼손 오염
# 오타공 오염
# 터짐 오염
# 오염 터짐
# 터짐 훼손
# 걸레받이수정 오염
# 훼손 오타공
# 훼손 터짐
# 훼손 오타공
# 훼손 오염
# 오타공 훼손
# 오염 훼손
# 터짐 훼손
# 터짐 훼손
# 석고수정 창틀,문틀수정
# 오염 몰딩수정
# 훼손 오염
# 터짐 창틀,문틀수정
# 터짐 오염
# 터짐 오염
# 오염 꼬임
# 오염 훼손
# 터짐 훼손
# 걸레받이수정 훼손
# 오타공 훼손
# 터짐 오염
# 터짐 오염
# 훼손 터짐
# 석고수정 훼손
# 터짐 훼손
# 터짐 오염
# 오염 터짐
# 훼손 터짐
# 면불량 오염
# 오염 훼손
# 오타공 훼손
# 훼손 오타공
# 훼손 오염
# 몰딩수정 터짐
# 터짐 훼손
# 터짐 훼손
# 오염 훼손
# 몰딩수정 훼손
# 오타공 훼손
# 오염 훼손
# 훼손 오염
# 훼손 오염
# 터짐 훼손
# 터짐 오염
# 석고수정 오염
# 터짐 훼손
# 터짐 훼손
# 훼손 터짐
# 훼손 터짐
# 오염 훼손
# 면불량 오타공
# 훼손 오염
# 오염 훼손
# 터짐 훼손
# 오염 훼손
# 터짐 훼손
# 터짐 훼손
# 터짐 꼬임
# 터짐 훼손
# 터짐 훼손
# 훼손 오타공
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 오타공 훼손
# 석고수정 오염
# 터짐 훼손
# 오염 훼손
# 오염 훼손
# 오타공 오염
# 터짐 훼손
# 훼손 오염
# 터짐 훼손
# 터짐 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오타공 훼손
# 터짐 오염
# 오염 창틀,문틀수정
# 면불량 훼손
# 터짐 훼손
# 훼손 터짐
# 터짐 훼손
# 걸레받이수정 훼손
# 오염 훼손
# 오염 훼손
# 몰딩수정 훼손
# 터짐 훼손
# 훼손 터짐
# 터짐 훼손
# 오염 훼손
# 터짐 훼손
# 오염 훼손
# 오타공 훼손
# 훼손 오염
# 오염 훼손
# 터짐 훼손
# 오염 터짐
# 터짐 훼손
# 터짐 훼손
# ...

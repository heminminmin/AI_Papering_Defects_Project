# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd(), os.path.pardir, 'functions'))
from compare_csv import compare_with_sample_csv_fn, compare_with_prev_csv_fn

PREV_FOLDER_NAME = '2_second'
PREV_CSV_FILE_NAME = 'baseline_submit.csv'

CURRENT_FOLDER_NAME = '3_third'
CURRENT_CSV_FILE_NAME = 'test_20230520_071751.csv'

compare_with_sample_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME)
compare_with_sample_csv_fn(CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)

compare_with_prev_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME, CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)
# Out:
# compare_with_sample_csv_fn() : 462
# compare_with_sample_csv_fn() : 403
# 오염 훼손
# 피스 훼손
# 훼손 오염
# 훼손 걸레받이수정
# 오염 터짐
# 석고수정 훼손
# 오염 가구수정
# 훼손 터짐
# 훼손 꼬임
# 터짐 걸레받이수정
# 곰팡이 걸레받이수정
# 훼손 오염
# 오타공 훼손
# 몰딩수정 훼손
# 오염 꼬임
# 훼손 터짐
# 걸레받이수정 훼손
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 훼손 걸레받이수정
# 훼손 오염
# 오염 꼬임
# 꼬임 들뜸
# 걸레받이수정 훼손
# 면불량 오염
# 석고수정 훼손
# 오염 면불량
# 들뜸 훼손
# 터짐 석고수정
# 오염 훼손
# 오염 걸레받이수정
# 오염 터짐
# 훼손 피스
# 오염 훼손
# 몰딩수정 훼손
# 터짐 훼손
# 오염 훼손
# 오염 훼손
# 훼손 면불량
# 오염 훼손
# 꼬임 훼손
# 곰팡이 몰딩수정
# 터짐 훼손
# 오염 몰딩수정
# 오염 훼손
# 오타공 훼손
# 훼손 걸레받이수정
# 꼬임 오염
# 이음부불량 훼손
# 오염 곰팡이
# 훼손 터짐
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 곰팡이
# 오타공 훼손
# 오염 걸레받이수정
# 들뜸 터짐
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 걸레받이수정 훼손
# 오염 터짐
# 오염 걸레받이수정
# 훼손 오염
# 터짐 오염
# 오염 훼손
# 오염 훼손
# 곰팡이 몰딩수정
# 훼손 오염
# 오염 터짐
# 오염 훼손
# 울음 오염
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 몰딩수정
# 훼손 오염
# 오타공 면불량
# 걸레받이수정 훼손
# 훼손 오타공
# 오염 훼손
# 피스 훼손
# 훼손 꼬임
# 훼손 몰딩수정
# 훼손 피스
# 터짐 걸레받이수정
# 훼손 오염
# 오염 훼손
# 오염 걸레받이수정
# 터짐 훼손
# 오염 훼손
# 오염 훼손
# 면불량 훼손
# 훼손 오타공
# 오염 훼손
# 오염 훼손
# 들뜸 훼손
# 훼손 몰딩수정
# 훼손 오타공
# 오염 면불량
# 오염 훼손
# 훼손 피스
# 피스 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 꼬임 훼손
# 훼손 걸레받이수정
# 곰팡이 몰딩수정
# 피스 훼손
# 오염 훼손
# 꼬임 오염
# 걸레받이수정 훼손
# 오염 훼손
# 훼손 오염
# 훼손 걸레받이수정
# 녹오염 훼손
# 오타공 훼손
# 창틀,문틀수정 꼬임
# 꼬임 들뜸
# 가구수정 훼손
# 훼손 석고수정
# 곰팡이 훼손
# 면불량 훼손
# 훼손 오염
# 석고수정 훼손
# 오염 훼손
# 오염 이음부불량
# 터짐 녹오염
# 오염 훼손
# 곰팡이 걸레받이수정
# 오염 훼손
# 오염 훼손
# 훼손 면불량
# 오염 걸레받이수정
# 오염 훼손
# 오염 훼손
# 터짐 오염
# 훼손 걸레받이수정
# 가구수정 훼손
# 터짐 훼손
# 훼손 면불량
# 터짐 훼손
# 오염 훼손
# 들뜸 몰딩수정
# 면불량 훼손
# 꼬임 몰딩수정
# 가구수정 훼손
# 오염 꼬임
# 터짐 훼손
# 오염 훼손
# 터짐 훼손
# 걸레받이수정 오염
# 오염 훼손
# 터짐 오염
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 오염 걸레받이수정
# 훼손 터짐
# 꼬임 훼손
# 면불량 훼손
# 훼손 몰딩수정
# 훼손 면불량
# 훼손 걸레받이수정
# 곰팡이 터짐
# 터짐 훼손
# 오염 터짐
# 오타공 훼손
# 터짐 훼손
# 터짐 오염
# 훼손 오염
# 꼬임 창틀,문틀수정
# 꼬임 면불량
# 오염 훼손
# 오염 훼손
# 훼손 석고수정
# 오염 석고수정
# 가구수정 몰딩수정
# 석고수정 면불량
# 오염 걸레받이수정
# 오염 훼손
# 피스 훼손
# 오염 훼손
# 오염 걸레받이수정
# 오염 훼손
# 훼손 몰딩수정
# 훼손 오염
# 훼손 석고수정
# 훼손 터짐
# 꼬임 가구수정
# 훼손 곰팡이
# 곰팡이 들뜸
# 오염 터짐
# 오염 면불량
# 훼손 피스
# 면불량 오염
# 터짐 훼손
# 터짐 훼손
# 꼬임 훼손
# 훼손 터짐
# 오타공 훼손
# 훼손 터짐
# 오염 몰딩수정
# 들뜸 몰딩수정
# 훼손 면불량
# 훼손 오타공
# 석고수정 훼손
# 훼손 면불량
# 훼손 면불량
# 오염 면불량
# 면불량 오염
# 오염 몰딩수정
# 훼손 오염
# 훼손 오염
# 오염 훼손
# 터짐 훼손
# 훼손 오염
# 오염 훼손
# 걸레받이수정 꼬임
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오염 걸레받이수정
# 오염 걸레받이수정
# 석고수정 훼손
# 들뜸 훼손
# 훼손 곰팡이
# 들뜸 몰딩수정
# 오염 훼손
# 걸레받이수정 훼손
# 오염 터짐
# 피스 면불량
# 오염 훼손
# 훼손 석고수정
# 오염 곰팡이
# 훼손 오염
# 면불량 오염
# 오염 훼손
# 오염 훼손
# 들뜸 꼬임
# 꼬임 면불량
# 꼬임 오염
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 훼손 터짐
# 면불량 걸레받이수정
# 오염 꼬임
# 오염 훼손
# 훼손 오타공
# 오염 곰팡이
# 들뜸 훼손
# 오염 훼손
# 훼손 오염
# 걸레받이수정 훼손
# 면불량 오염
# 오염 훼손
# 훼손 면불량
# 녹오염 훼손
# 터짐 몰딩수정
# 오염 터짐
# 오염 훼손
# 훼손 오염
# 훼손 면불량
# 훼손 창틀,문틀수정
# 훼손 오염
# 오염 면불량
# 훼손 창틀,문틀수정
# 꼬임 창틀,문틀수정
# 오염 터짐
# 피스 훼손
# 꼬임 훼손
# 꼬임 훼손
# 석고수정 피스
# 오염 터짐
# 훼손 걸레받이수정
# 꼬임 터짐
# 오염 울음
# 오염 훼손
# 오염 꼬임
# 훼손 몰딩수정
# 오염 몰딩수정
# 오염 석고수정
# 꼬임 걸레받이수정
# 훼손 오염
# 오타공 훼손
# 오염 가구수정
# 오타공 훼손
# 꼬임 훼손
# 오염 오타공
# 오염 훼손
# 터짐 훼손
# 훼손 걸레받이수정
# 오염 훼손
# 꼬임 훼손
# 오염 터짐
# 오염 훼손
# 창틀,문틀수정 몰딩수정
# compare_with_prev_csv_fn() : 306

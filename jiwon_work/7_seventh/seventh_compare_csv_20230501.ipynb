# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), os.path.pardir))

from compare_csv_fn_new import compare_with_sample_csv_fn
from compare_csv_fn_new import compare_with_prev_csv_fn

PREV_CSV_FILE_NAME = 'baseline_submit.csv'
CURRENT_CSV_FILE_NAME = 'test_20230501_213749.csv'

PREV_FOLDER_NAME = '2_second'
CURRENT_FOLDER_NAME = '7_seventh'

compare_with_sample_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME)
compare_with_sample_csv_fn(CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)

compare_with_prev_csv_fn(PREV_FOLDER_NAME, PREV_CSV_FILE_NAME, CURRENT_FOLDER_NAME, CURRENT_CSV_FILE_NAME)
# Out:
# compare_with_sample_csv_fn() : 462
# compare_with_sample_csv_fn() : 455
# 훼손 터짐
# 몰딩수정 오타공
# 오염 터짐
# 훼손 오염
# 훼손 터짐
# 오염 걸레받이수정
# 오타공 훼손
# 몰딩수정 훼손
# 피스 훼손
# 오염 훼손
# 훼손 오염
# 오염 오타공
# 석고수정 훼손
# 걸레받이수정 오염
# 오염 터짐
# 오염 터짐
# 오염 석고수정
# 훼손 오염
# 오염 훼손
# 훼손 터짐
# 훼손 터짐
# 곰팡이 오염
# 훼손 오염
# 훼손 터짐
# 훼손 걸레받이수정
# 오염 오타공
# 곰팡이 터짐
# 훼손 터짐
# 훼손 석고수정
# 오타공 훼손
# 몰딩수정 터짐
# 오염 터짐
# 오염 훼손
# 훼손 오염
# 면불량 훼손
# 오염 면불량
# 걸레받이수정 오염
# 오염 훼손
# 오염 오타공
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 훼손 몰딩수정
# 훼손 터짐
# 훼손 터짐
# 훼손 오염
# 훼손 몰딩수정
# 오염 훼손
# 몰딩수정 터짐
# 오염 터짐
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 터짐
# 오염 석고수정
# 오염 터짐
# 꼬임 오염
# 훼손 터짐
# 오염 훼손
# 걸레받이수정 오염
# 오염 면불량
# 면불량 훼손
# 석고수정 훼손
# 훼손 오타공
# 들뜸 터짐
# 터짐 오염
# 오염 훼손
# 오염 터짐
# 오염 훼손
# 훼손 터짐
# 훼손 터짐
# 오염 훼손
# 훼손 터짐
# 훼손 터짐
# 훼손 터짐
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 훼손 터짐
# 터짐 훼손
# 훼손 오타공
# 오염 석고수정
# 가구수정 터짐
# 몰딩수정 오염
# 훼손 오염
# 터짐 오타공
# 훼손 터짐
# 훼손 터짐
# 오염 터짐
# 훼손 터짐
# 훼손 오염
# 훼손 오염
# 훼손 오염
# 훼손 오타공
# 오염 터짐
# 꼬임 오염
# 곰팡이 면불량
# 훼손 터짐
# 훼손 걸레받이수정
# 꼬임 오염
# 오염 훼손
# 훼손 몰딩수정
# 오염 터짐
# 면불량 훼손
# 오염 훼손
# 오타공 터짐
# 훼손 오염
# 오염 터짐
# 훼손 오타공
# 오타공 훼손
# 훼손 오염
# 꼬임 훼손
# 오염 훼손
# 훼손 오염
# 훼손 터짐
# 이음부불량 오염
# 오염 훼손
# 오염 터짐
# 훼손 터짐
# 훼손 터짐
# 오염 석고수정
# 오염 훼손
# 오염 훼손
# 훼손 터짐
# 훼손 오염
# 훼손 오염
# 훼손 석고수정
# 오염 터짐
# 오염 훼손
# 꼬임 훼손
# 오염 훼손
# 오타공 오염
# 훼손 터짐
# 꼬임 훼손
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 오타공
# 꼬임 훼손
# 꼬임 훼손
# 들뜸 오염
# 꼬임 오염
# 훼손 오염
# 오염 몰딩수정
# 오염 훼손
# 곰팡이 훼손
# 이음부불량 훼손
# 꼬임 훼손
# 오염 훼손
# 오염 훼손
# 창틀,문틀수정 터짐
# 꼬임 오염
# 걸레받이수정 훼손
# 훼손 오염
# 오염 오타공
# 훼손 오염
# 꼬임 훼손
# 오염 훼손
# 훼손 터짐
# 훼손 오염
# 터짐 오타공
# 오염 훼손
# 훼손 걸레받이수정
# 오염 훼손
# 훼손 터짐
# 오염 훼손
# 오염 오타공
# 오염 터짐
# 곰팡이 터짐
# 오염 터짐
# 오염 터짐
# 훼손 터짐
# 오염 오타공
# 꼬임 오염
# 오염 훼손
# 오염 오타공
# 오염 터짐
# 오염 터짐
# 훼손 터짐
# 울음 면불량
# 터짐 오염
# 오염 훼손
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 오타공 터짐
# 걸레받이수정 훼손
# 훼손 오염
# 녹오염 훼손
# 몰딩수정 훼손
# 오염 터짐
# 훼손 오염
# 훼손 면불량
# 피스 터짐
# 훼손 터짐
# 훼손 오염
# 꼬임 터짐
# 오염 훼손
# 훼손 터짐
# 훼손 오염
# 훼손 오타공
# 꼬임 터짐
# 꼬임 훼손
# 꼬임 오염
# 몰딩수정 오염
# 훼손 오염
# 오염 훼손
# 녹오염 걸레받이수정
# 오염 훼손
# 오염 터짐
# 터짐 훼손
# 오염 훼손
# 훼손 터짐
# 오염 훼손
# 면불량 훼손
# 오염 걸레받이수정
# 오염 훼손
# 오염 훼손
# 들뜸 터짐
# 곰팡이 터짐
# 훼손 오염
# 훼손 오타공
# 훼손 석고수정
# 훼손 터짐
# 오염 터짐
# 피스 훼손
# 오염 훼손
# 오염 몰딩수정
# 훼손 터짐
# 꼬임 훼손
# 꼬임 오염
# 훼손 터짐
# 곰팡이 훼손
# 피스 오타공
# 훼손 오염
# 오염 훼손
# 터짐 오염
# 오염 훼손
# 터짐 훼손
# 꼬임 오염
# 걸레받이수정 터짐
# 오염 훼손
# 오염 훼손
# 오염 걸레받이수정
# 훼손 오염
# 훼손 오염
# 훼손 터짐
# 오염 훼손
# 녹오염 터짐
# 오타공 훼손
# 훼손 오염
# 훼손 오염
# 피스 터짐
# 터짐 오염
# 훼손 터짐
# 창틀,문틀수정 오염
# 터짐 오염
# 꼬임 오타공
# 오염 몰딩수정
# 가구수정 오염
# 걸레받이수정 훼손
# 오염 훼손
# 오염 터짐
# 오염 훼손
# 걸레받이수정 훼손
# 오염 터짐
# 오염 훼손
# 훼손 오염
# 곰팡이 훼손
# 오타공 오염
# 피스 터짐
# 면불량 오타공
# 훼손 터짐
# 훼손 터짐
# 석고수정 훼손
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 훼손 터짐
# 훼손 오염
# 훼손 터짐
# 터짐 걸레받이수정
# 오염 훼손
# 곰팡이 훼손
# 오염 몰딩수정
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 터짐 오염
# 터짐 오타공
# 훼손 오염
# 꼬임 터짐
# 오염 걸레받이수정
# 가구수정 오타공
# 터짐 훼손
# 훼손 터짐
# 훼손 오염
# 곰팡이 훼손
# 오염 훼손
# 오염 터짐
# 오염 훼손
# 오염 터짐
# 몰딩수정 오염
# 훼손 터짐
# 몰딩수정 훼손
# 오염 터짐
# 터짐 훼손
# 오염 훼손
# 들뜸 훼손
# 훼손 오염
# 면불량 훼손
# 훼손 오염
# 꼬임 오염
# 피스 훼손
# 가구수정 훼손
# 훼손 터짐
# 오염 터짐
# 터짐 면불량
# 오염 오타공
# 터짐 훼손
# 오염 오타공
# 터짐 훼손
# 걸레받이수정 몰딩수정
# 오염 몰딩수정
# 훼손 터짐
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 오염 터짐
# 꼬임 터짐
# 오염 터짐
# 면불량 훼손
# 훼손 오염
# 훼손 터짐
# 훼손 터짐
# 훼손 터짐
# 훼손 오염
# 곰팡이 터짐
# 훼손 면불량
# 곰팡이 오타공
# 터짐 석고수정
# 오염 터짐
# 오염 터짐
# 오타공 터짐
# 터짐 훼손
# 터짐 훼손
# 훼손 터짐
# 꼬임 오염
# 오염 훼손
# 꼬임 훼손
# 몰딩수정 오염
# 곰팡이 훼손
# 오염 훼손
# 오염 터짐
# 오염 훼손
# 훼손 터짐
# 가구수정 훼손
# 석고수정 면불량
# 오염 훼손
# 꼬임 훼손
# 오염 훼손
# 석고수정 훼손
# 오염 터짐
# 피스 터짐
# 오염 훼손
# 오염 훼손
# 오염 터짐
# 오염 훼손
# 훼손 오타공
# 오타공 오염
# 훼손 오염
# 꼬임 오염
# 오염 터짐
# 훼손 터짐
# 훼손 오염
# 곰팡이 오염
# 오타공 오염
# 오염 걸레받이수정
# 가구수정 오염
# 꼬임 훼손
# 오염 터짐
# 훼손 터짐
# 훼손 오염
# 오염 훼손
# 꼬임 터짐
# 이음부불량 훼손
# 면불량 몰딩수정
# 오염 훼손
# 터짐 오염
# 오염 터짐
# 터짐 훼손
# 오염 터짐
# 꼬임 터짐
# 오염 훼손
# 오염 터짐
# 훼손 터짐
# 훼손 터짐
# 오타공 훼손
# 훼손 터짐
# 들뜸 터짐
# 훼손 터짐
# 훼손 터짐
# 석고수정 터짐
# 훼손 오염
# 오염 훼손
# 오염 터짐
# 훼손 오염
# 훼손 오염
# 터짐 훼손
# 오염 훼손
# 면불량 오염
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오염 터짐
# 오염 오타공
# 오염 훼손
# 오염 석고수정
# 훼손 터짐
# 터짐 오타공
# 훼손 오염
# 훼손 터짐
# 오염 훼손
# 오염 훼손
# 걸레받이수정 훼손
# 오염 걸레받이수정
# 훼손 걸레받이수정
# 오염 걸레받이수정
# 오염 터짐
# 오염 터짐
# 석고수정 훼손
# 들뜸 오염
# 오염 훼손
# 오염 훼손
# 훼손 터짐
# 들뜸 터짐
# 걸레받이수정 면불량
# 오염 터짐
# 오염 오타공
# 피스 터짐
# 오염 훼손
# 훼손 오염
# 훼손 오염
# 오타공 훼손
# 오타공 오염
# 걸레받이수정 터짐
# 오염 훼손
# 면불량 몰딩수정
# 오염 훼손
# 오염 오타공
# 오염 훼손
# 오염 터짐
# 훼손 걸레받이수정
# 오염 훼손
# 훼손 오염
# 꼬임 오염
# 들뜸 터짐
# 훼손 오염
# 이음부불량 터짐
# 꼬임 훼손
# 터짐 훼손
# 꼬임 훼손
# 걸레받이수정 터짐
# 훼손 터짐
# 훼손 터짐
# 오염 터짐
# 곰팡이 터짐
# 터짐 오염
# 오염 훼손
# 오염 터짐
# 훼손 터짐
# 훼손 터짐
# 훼손 터짐
# 면불량 오타공
# 오염 훼손
# 오염 터짐
# 훼손 오염
# 오염 훼손
# 오염 터짐
# 오염 터짐
# 훼손 터짐
# 들뜸 터짐
# 꼬임 오염
# 오염 훼손
# 오염 훼손
# 걸레받이수정 오염
# 면불량 훼손
# 오염 훼손
# 훼손 터짐
# 훼손 오염
# 훼손 터짐
# 녹오염 터짐
# 오염 터짐
# 꼬임 훼손
# 터짐 훼손
# 오염 훼손
# 오염 훼손
# 훼손 터짐
# 오타공 훼손
# 걸레받이수정 훼손
# 훼손 면불량
# 꼬임 훼손
# 훼손 터짐
# 훼손 오타공
# 오염 터짐
# 오염 터짐
# 훼손 터짐
# 꼬임 오염
# 오염 터짐
# 오염 오타공
# 피스 몰딩수정
# 훼손 터짐
# 오염 터짐
# 꼬임 오염
# 훼손 터짐
# 훼손 오염
# 오염 훼손
# 몰딩수정 훼손
# 피스 터짐
# 훼손 오타공
# 몰딩수정 오염
# 꼬임 터짐
# 훼손 오염
# 석고수정 훼손
# 훼손 오염
# 오염 터짐
# 훼손 오염
# 훼손 오타공
# 꼬임 훼손
# 오염 훼손
# 오염 석고수정
# 창틀,문틀수정 터짐
# 오염 터짐
# 오염 훼손
# 오염 오타공
# 훼손 터짐
# 걸레받이수정 터짐
# 오염 훼손
# 훼손 오염
# 곰팡이 터짐
# 오염 터짐
# 훼손 오염
# 오염 석고수정
# 오염 훼손
# 오염 터짐
# 오염 훼손
# 오염 터짐
# 꼬임 터짐
# 훼손 오염
# 오염 몰딩수정
# 오타공 터짐
# 훼손 오염
# 오염 터짐
# 오염 훼손
# 오염 훼손
# 꼬임 훼손
# 오타공 터짐
# 훼손 터짐
# 꼬임 오염
# 훼손 오염
# 오염 터짐
# 훼손 면불량
# 훼손 오염
# 터짐 오타공
# 훼손 터짐
# 훼손 오염
# 훼손 터짐
# 오염 훼손
# 훼손 오염
# 훼손 터짐
# 꼬임 터짐
# 오염 터짐
# 오염 터짐
# 창틀,문틀수정 터짐
# compare_with_prev_csv_fn() : 580

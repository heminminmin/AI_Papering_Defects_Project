# %%
# 사용 가능한 GPU 확인
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# GPU 사용 설정
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13976598407122272957
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6290407424
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11896244290553401534
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:01:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# pip3 install tensorflow
from tensorflow.keras.layers import Conv2D, Dropout, Flatten, Dense
from tensorflow.keras import Input, Sequential
import numpy as np

# pip3 uninstall keras
# pip3 uninstall tensorflow
# pip3 install tensorflow --user

# ------------------------------------------------

# 객체 순회 및 작업 진행률 표시
# pip3 install tqdm
from tqdm import tqdm

# 이미지 프로세싱
# pip3 install opencv-python
import cv2

# 이미지 로드 시 옵션 설정
# pip3 install pillow
from PIL import ImageFile

# 데이터 시각화
# pip3 install matplotlib
import matplotlib.pyplot as plt

# ------------------------------------------------

# 디렉토리 접근
import sys

sys.path.append(os.path.join(os.getcwd(), os.path.pardir, 'functions'))

# from 파일명 import 함수명
from get_train_list import get_train_image_paths_and_encoding_labels_fn
from predict_and_test import get_predict_result_fn, get_test_csv_fn
from get_img_tensor import get_tensor_through_imgs_fn

# pip3 install scikit-learn
from sklearn.model_selection import train_test_split
from datetime import datetime

# %%
# ========== 특정 파일 1개 불러와서 표시하기 ==========

# img_path = 'open/test/000.png'
# plt.imshow(imread(img_path))
# plt.show()

# ===================================================

# %%
# ======== 학습용 이미지 경로와 라벨에 대한 각각의 리스트 생성하기 ========

train_image_paths, encoding_labels = get_train_image_paths_and_encoding_labels_fn()

# =====================================================================
# Out:
# encoding_labels.shape : (3457, 19)

# %%
# ========= 학습용 이미지 리스트에서 20개만 확인해보기 =========

fig = plt.figure()

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

for index in range(20):

    ax = fig.add_subplot(4, 5, index + 1, xticks=[], yticks=[])
    img_path = train_image_paths[index]

    # img_name = [*os.path.split(img_path)].pop()
    # defect_type = encoding_labels[index]

    # 하자 유형_이미지 파일명.확장자
    # title = f'{defect_type}_{img_name}'
    # print('title :', title)

    # ax.set_title(title, fontsize=6)

    # issue: None
    # cause: 경로에 한글이 포함될 경우 발생함
    # img = cv2.imread(img_path)

    # solved
    img_array = np.fromfile(img_path, np.uint8)
    img = cv2.imdecode(img_array, cv2.IMREAD_UNCHANGED)

    # error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
    # solved: img 유무 확인하기
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# ============================================================

# %%
# ========= 교수님 코드 따라서 이미지 데이터를 가져오고 차원 변형하기 =========

# 잘린 이미지에 대한 로드 여부 설정
ImageFile.LOAD_TRUNCATED_IMAGES = True

RESIZED_WIDTH = 100
RESIZED_HEIGHT = 100

fig = plt.figure()

train_image_tensor = get_tensor_through_imgs_fn(train_image_paths, RESIZED_HEIGHT, RESIZED_WIDTH, fig)
print('train_image_tensor.shape :', train_image_tensor.shape)

# =========================================================================
# Out:
#   0%|          | 0/3457 [00:00<?, ?it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 1/3457 [00:00<27:13,  2.12it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|██████████| 3457/3457 [01:13<00:00, 46.76it/s]
# train_image_tensor.shape : (3457, 100, 100, 3)

# %%
# ======== 교수님의 donkey_car_CNN 코드 따라서 학습시키기 ========

# 데이콘 리더 보드 점수 => 0.299285797%

EPOCHS = 40

# 학습 시킬 이미지 데이터에 대하여 정규화 (0 ~ 1)
normalized_train_image_tensor = train_image_tensor / 255
print('normalized_train_image_tensor.shape :',
      normalized_train_image_tensor.shape)

# 9:1 비율로 학습 시 사용할 데이터와 추론 시 사용할 데이터로 분리하고 랜덤성 부여
# x_for_train, x_test, y_for_train, y_test = train_test_split(
#     normalized_image_tensor, encoding_labels, test_size=0.1)

# 9:1 비율로 학습용 데이터와 검증용 데이터로 분리
# train_data_count = int(len(x_for_train) * 0.9)
# x_valid, y_valid = x_for_train[train_data_count:], y_for_train[train_data_count:]
# x_train, y_train = x_for_train[:train_data_count], y_for_train[:train_data_count]

# train 폴더 내의 모든 이미지 데이터에 대하여 학습 진행 (1개는 학습 중에 검증용 데이터로 사용)
x_train, x_valid, y_train, y_valid = train_test_split(
    normalized_train_image_tensor, encoding_labels, test_size=1)

model = Sequential([
    Input(shape=(RESIZED_WIDTH, RESIZED_HEIGHT, 3)),
    Conv2D(24, (5, 5), strides=(
        2, 2), padding='same', activation='relu'),
    Dropout(0.2),
    Conv2D(32, (5, 5), strides=(
        2, 2), padding='same', activation='relu'),
    Dropout(0.2),
    Conv2D(64, (5, 5), strides=(
        2, 2), padding='same', activation='relu'),
    Dropout(0.2),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    Dropout(0.2),
    Conv2D(64, (3, 3), activation='relu'),
    Dropout(0.2),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.2),
    Dense(50, activation='relu'),
    Dropout(0.2),
    Dense(19, activation='softmax'),
])

model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['acc'])

print('x_train.shape :', x_train.shape)
print('y_train.shape :', y_train.shape)

history = model.fit(x_train, y_train, epochs=EPOCHS,
                    validation_data=(x_valid, y_valid))

# 연월일_시간
now = datetime.today().strftime('%Y%m%d_%H%M%S')
model.save(f'model_{now}.h5')

# =============================================
# Out:
# normalized_train_image_tensor.shape : (3457, 100, 100, 3)
# x_train.shape : (3456, 100, 100, 3)
# y_train.shape : (3456, 19)
# Epoch 1/40
# 108/108 [==============================] - 13s 9ms/step - loss: 2.2884 - acc: 0.3764 - val_loss: 1.6274 - val_acc: 0.0000e+00
# Epoch 2/40
# 108/108 [==============================] - 1s 7ms/step - loss: 2.0875 - acc: 0.3924 - val_loss: 1.6160 - val_acc: 0.0000e+00
# Epoch 3/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.9887 - acc: 0.4002 - val_loss: 1.0027 - val_acc: 0.0000e+00
# Epoch 4/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.9321 - acc: 0.3984 - val_loss: 1.4965 - val_acc: 0.0000e+00
# Epoch 5/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.8942 - acc: 0.4158 - val_loss: 1.3335 - val_acc: 0.0000e+00
# Epoch 6/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.8253 - acc: 0.4337 - val_loss: 1.5249 - val_acc: 0.0000e+00
# Epoch 7/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.7718 - acc: 0.4421 - val_loss: 1.5367 - val_acc: 0.0000e+00
# Epoch 8/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.6963 - acc: 0.4552 - val_loss: 1.6013 - val_acc: 0.0000e+00
# Epoch 9/40
# 108/108 [==============================] - 1s 6ms/step - loss: 1.6409 - acc: 0.4789 - val_loss: 1.3635 - val_acc: 0.0000e+00
# Epoch 10/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.5912 - acc: 0.4876 - val_loss: 1.3165 - val_acc: 0.0000e+00
# Epoch 11/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.5255 - acc: 0.5049 - val_loss: 1.5873 - val_acc: 0.0000e+00
# Epoch 12/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.4531 - acc: 0.5237 - val_loss: 1.6156 - val_acc: 0.0000e+00
# Epoch 13/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.3944 - acc: 0.5350 - val_loss: 1.5804 - val_acc: 0.0000e+00
# Epoch 14/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.3487 - acc: 0.5388 - val_loss: 1.6080 - val_acc: 0.0000e+00
# Epoch 15/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.2595 - acc: 0.5666 - val_loss: 1.9300 - val_acc: 0.0000e+00
# Epoch 16/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.2067 - acc: 0.5819 - val_loss: 1.9240 - val_acc: 0.0000e+00
# Epoch 17/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.0969 - acc: 0.6126 - val_loss: 2.0474 - val_acc: 0.0000e+00
# Epoch 18/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.0714 - acc: 0.6201 - val_loss: 2.9390 - val_acc: 0.0000e+00
# Epoch 19/40
# 108/108 [==============================] - 1s 7ms/step - loss: 1.0079 - acc: 0.6487 - val_loss: 2.9038 - val_acc: 0.0000e+00
# Epoch 20/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.9530 - acc: 0.6667 - val_loss: 2.5752 - val_acc: 0.0000e+00
# Epoch 21/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.8989 - acc: 0.6768 - val_loss: 2.6830 - val_acc: 0.0000e+00
# Epoch 22/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.8363 - acc: 0.6988 - val_loss: 3.3127 - val_acc: 0.0000e+00
# Epoch 23/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.8023 - acc: 0.7080 - val_loss: 2.7277 - val_acc: 0.0000e+00
# Epoch 24/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.7363 - acc: 0.7373 - val_loss: 2.6198 - val_acc: 0.0000e+00
# Epoch 25/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.7441 - acc: 0.7373 - val_loss: 2.8903 - val_acc: 0.0000e+00
# Epoch 26/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6587 - acc: 0.7650 - val_loss: 2.8268 - val_acc: 0.0000e+00
# Epoch 27/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6577 - acc: 0.7616 - val_loss: 5.1941 - val_acc: 0.0000e+00
# Epoch 28/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6062 - acc: 0.7781 - val_loss: 3.1912 - val_acc: 0.0000e+00
# Epoch 29/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5703 - acc: 0.8012 - val_loss: 8.0323 - val_acc: 0.0000e+00
# Epoch 30/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5855 - acc: 0.7969 - val_loss: 6.4723 - val_acc: 0.0000e+00
# Epoch 31/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5394 - acc: 0.8047 - val_loss: 6.7833 - val_acc: 0.0000e+00
# Epoch 32/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.4899 - acc: 0.8316 - val_loss: 5.5638 - val_acc: 0.0000e+00
# Epoch 33/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.4748 - acc: 0.8281 - val_loss: 8.6524 - val_acc: 0.0000e+00
# Epoch 34/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4521 - acc: 0.8365 - val_loss: 8.6459 - val_acc: 0.0000e+00
# Epoch 35/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4338 - acc: 0.8487 - val_loss: 8.7693 - val_acc: 0.0000e+00
# Epoch 36/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4013 - acc: 0.8576 - val_loss: 11.1030 - val_acc: 0.0000e+00
# Epoch 37/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.4469 - acc: 0.8461 - val_loss: 10.1415 - val_acc: 0.0000e+00
# Epoch 38/40
# 108/108 [==============================] - 1s 7ms/step - loss: 0.4062 - acc: 0.8565 - val_loss: 9.4891 - val_acc: 0.0000e+00
# Epoch 39/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3794 - acc: 0.8721 - val_loss: 12.9310 - val_acc: 0.0000e+00
# Epoch 40/40
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3566 - acc: 0.8762 - val_loss: 16.6706 - val_acc: 0.0000e+00

# %%
# ======= 학습 횟수에 따른 오차 변화 그래프 =======

loss = history.history['loss']
print('loss :', loss)

plt.plot(range(1, EPOCHS + 1), loss, 'g')
plt.title = 'Tranning Loss'
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# ===============================================
# Out:
# loss : [2.2884109020233154, 2.087468147277832, 1.9887268543243408, 1.932132601737976, 1.894214153289795, 1.8252815008163452, 1.7718111276626587, 1.6963295936584473, 1.6408684253692627, 1.5911917686462402, 1.5255404710769653, 1.4531102180480957, 1.3944456577301025, 1.3487144708633423, 1.2594528198242188, 1.2066950798034668, 1.0969029664993286, 1.071352243423462, 1.0078980922698975, 0.9529834985733032, 0.8988721370697021, 0.8363322019577026, 0.802295446395874, 0.7362669706344604, 0.7441186308860779, 0.6587013006210327, 0.6576626300811768, 0.6061714291572571, 0.5703349709510803, 0.5854710936546326, 0.5394032001495361, 0.48986339569091797, 0.47484105825424194, 0.45214226841926575, 0.433765172958374, 0.40126025676727295, 0.44687411189079285, 0.40618136525154114, 0.37942758202552795, 0.3566286861896515]

# %%
# ================== 테스트 파일로 추론해보기 ==================

predict_result = get_predict_result_fn(RESIZED_WIDTH, RESIZED_HEIGHT, model)
get_test_csv_fn(predict_result)

# ============================================================
# Out:
# 100%|██████████| 792/792 [00:00<00:00, 391224.68it/s]
#   0%|          | 0/792 [00:00<?, ?it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 2/792 [00:00<01:06, 11.80it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|██████████| 792/792 [00:18<00:00, 42.35it/s]
# normalized_test_image_tensor.shape : (792, 100, 100, 3)
# 25/25 [==============================] - 0s 14ms/step
# predicted_result.shape : (792, 19)
# predicted_labels : ['훼손', '훼손', '훼손', '훼손', '훼손', '피스', '훼손', '훼손', '들뜸', '오타공', '걸레받이수정', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '꼬임', '걸레받이수정', '훼손', '훼손', '훼손', '훼손', '석고수정', '오염', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '오염', '몰딩수정', '훼손', '꼬임', '훼손', '곰팡이', '훼손', '석고수정', '훼손', '훼손', '훼손', '훼손', '훼손', '곰팡이', '오염', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '오타공', '피스', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '오염', '석고수정', '훼손', '걸레받이수정', '훼손', '훼손', '훼손', '오염', '오염', '훼손', '훼손', '꼬임', '오염', '훼손', '오염', '훼손', '걸레받이수정', '훼손', '꼬임', '면불량', '훼손', '걸레받이수정', '오염', '훼손', '터짐', '훼손', '훼손', '훼손', '걸레받이수정', '오타공', '걸레받이수정', '훼손', '훼손', '오염', '훼손', '오염', '오염', '오염', '훼손', '훼손', '오염', '오염', '훼손', '오타공', '오염', '오염', '훼손', '훼손', '훼손', '오염', '면불량', '훼손', '훼손', '훼손', '훼손', '녹오염', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '꼬임', '오염', '훼손', '오염', '훼손', '걸레받이수정', '훼손', '훼손', '훼손', '훼손', '오염', '오염', '훼손', '훼손', '석고수정', '훼손', '석고수정', '곰팡이', '훼손', '훼손', '훼손', '오염', '훼손', '이음부불량', '훼손', '오염', '피스', '걸레받이수정', '오염', '곰팡이', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '터짐', '훼손', '훼손', '훼손', '훼손', '꼬임', '훼손', '오타공', '훼손', '꼬임', '훼손', '오염', '훼손', '훼손', '훼손', '오타공', '꼬임', '훼손', '꼬임', '훼손', '꼬임', '오염', '오염', '오염', '훼손', '걸레받이수정', '훼손', '이음부불량', '훼손', '걸레받이수정', '오염', '꼬임', '훼손', '훼손', '꼬임', '오염', '몰딩수정', '오염', '훼손', '훼손', '꼬임', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '오염', '오타공', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '들뜸', '면불량', '훼손', '훼손', '곰팡이', '훼손', '훼손', '훼손', '오염', '꼬임', '터짐', '훼손', '훼손', '꼬임', '면불량', '훼손', '훼손', '훼손', '꼬임', '훼손', '훼손', '훼손', '면불량', '걸레받이수정', '오염', '오염', '훼손', '오염', '오염', '면불량', '걸레받이수정', '들뜸', '걸레받이수정', '오타공', '훼손', '오염', '곰팡이', '훼손', '훼손', '곰팡이', '훼손', '오염', '가구수정', '훼손', '걸레받이수정', '훼손', '훼손', '훼손', '훼손', '꼬임', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '오염', '오염', '오염', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '오염', '훼손', '들뜸', '훼손', '훼손', '걸레받이수정', '꼬임', '훼손', '곰팡이', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '면불량', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '터짐', '곰팡이', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '오타공', '훼손', '훼손', '곰팡이', '훼손', '훼손', '들뜸', '터짐', '훼손', '훼손', '훼손', '훼손', '오타공', '훼손', '훼손', '걸레받이수정', '오염', '훼손', '훼손', '훼손', '오염', '꼬임', '훼손', '피스', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '걸레받이수정', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '오타공', '훼손', '곰팡이', '훼손', '걸레받이수정', '오염', '훼손', '훼손', '훼손', '훼손', '가구수정', '훼손', '훼손', '훼손', '훼손', '훼손', '창틀,문틀수정', '훼손', '이음부불량', '오염', '오염', '오타공', '훼손', '꼬임', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '터짐', '훼손', '훼손', '꼬임', '오염', '훼손', '훼손', '오염', '훼손', '훼손', '터짐', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '꼬임', '훼손', '훼손', '걸레받이수정', '훼손', '훼손', '오염', '꼬임', '훼손', '훼손', '훼손', '들뜸', '오염', '오염', '꼬임', '훼손', '훼손', '훼손', '훼손', '훼손', '몰딩수정', '훼손', '훼손', '오염', '오염', '훼손', '걸레받이수정', '훼손', '오염', '걸레받이수정', '훼손', '훼손', '오염', '오염', '훼손', '훼손', '훼손', '걸레받이수정', '오염', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '면불량', '훼손', '훼손', '훼손', '훼손', '오염', '오염', '오타공', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '꼬임', '걸레받이수정', '훼손', '훼손', '훼손', '걸레받이수정', '훼손', '오염', '훼손', '오염', '훼손', '꼬임', '훼손', '오염', '꼬임', '훼손', '오염', '훼손', '훼손', '울음', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '곰팡이', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '걸레받이수정', '훼손', '터짐', '훼손', '훼손', '훼손', '피스', '훼손', '오염', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '이음부불량', '훼손', '훼손', '오염', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '훼손', '피스', '훼손', '곰팡이', '훼손', '훼손', '꼬임', '훼손', '오염', '훼손', '오염', '걸레받이수정', '훼손', '들뜸', '훼손', '터짐', '훼손', '훼손', '오염', '오염', '훼손', '오염', '훼손', '오염', '훼손', '오염', '훼손', '훼손', '들뜸', '훼손', '면불량', '훼손', '훼손', '면불량', '오염', '훼손', '훼손', '오염', '훼손', '훼손', '오염', '피스', '곰팡이', '오염', '훼손', '훼손', '훼손', '훼손', '훼손', '오염', '훼손', '훼손', '훼손', '걸레받이수정', '석고수정', '훼손', '오염', '훼손', '오염', '오타공', '피스', '훼손', '훼손', '면불량', '훼손', '오염', '오타공', '오염', '훼손', '오염', '훼손', '터짐', '훼손', '훼손', '오염', '훼손', '꼬 ...
